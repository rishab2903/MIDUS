# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Loading data into Python

# %%
df=pd.read_csv('~/Downloads/HDdataV2.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  W1A1PAGE_M2  W1A1PRSEX  W1QL2  W1QL3  W1HH_CELL  W1NPRB_SEX  \
# 0           0           53          1      9      9          9         999
# 1           1           60          1      1      1          3          50
# 2           2           69          1      1      1          3          65
# 3           3           70          2      9      9          9         999
# 4           4           51          2      9      9          9         999
#
#    W1SEX_CELL  W1NPRB_WHO  W1WHO  ...  W3HD6  W3HD7  W3HD8  W3HD9  W3HD10  \
# 0           9         999      9  ...     99     99     99     99      99
# 1           1         100      1  ...      0      0      0      0       1
# 2           1         100      1  ...  99999  99999  99999  99999   99999
# 3           9         999      9  ...  99999  99999  99999  99999   99999
# 4           9         999      9  ...  99999  99999  99999  99999   99999
#
#    W3HD11  W3HD12  W3HD13  W3HDsum  W3HDfinal
# ...

# %% [markdown]
# dropping columns which has name "HD" in it, since they are irrelevant

# %%
df = df[df.columns.drop(list(df.filter(regex='HD')))]

# %%
df.head()
# Out:
#    Unnamed: 0  W1A1PAGE_M2  W1A1PRSEX  W1QL2  W1QL3  W1HH_CELL  W1NPRB_SEX  \
# 0           0           53          1      9      9          9         999
# 1           1           60          1      1      1          3          50
# 2           2           69          1      1      1          3          65
# 3           3           70          2      9      9          9         999
# 4           4           51          2      9      9          9         999
#
#    W1SEX_CELL  W1NPRB_WHO  W1WHO  ...  W1A1SS15_9  W1A1SS15_10  W1A1SS16  \
# 0           9         999      9  ...           8            8         4
# 1           1         100      1  ...       99999        99999     99999
# 2           1         100      1  ...           9            9         9
# 3           9         999      9  ...           9            9         9
# 4           9         999      9  ...           9            9         9
#
#    W1A1SS17  W1A1ST1  W1A1ST2  W1A1ST3  W1A1ST4  W1A1ST5  W1A1SSATIS
# ...

# %% [markdown]
# Creating a subset of df containg only columns which has data related to finance

# %%
df_financial = df.filter(regex='A1SJ')

# %%
df_financial
# Out:
#       W1A1SJCSD  W1A1SJCDA  W1A1SJCDS  W1A1SJCCS  W1A1SJCSS  W1A1SJ1  W1A1SJ2  \
# 0         99999      99999      99999      99999      99999        8        5
# 1         99999      99999      99999      99999      99999    99999    99999
# 2         99999      99999      99999      99999      99999        6        6
# 3         99999      99999      99999      99999      99999       98       10
# 4         99999      99999      99999      99999      99999        1        7
# ...         ...        ...        ...        ...        ...      ...      ...
# 7099      99999      99999      99999      99999      99999        5        5
# 7100      99999      99999      99999      99999      99999    99999    99999
# 7101      99999      99999      99999      99999      99999        9        6
# 7102      99999      99999      99999      99999      99999        8        6
# 7103      99999      99999      99999      99999      99999        5        5
#
# ...

# %% [markdown]
# dropping first 5 columns since they are irrelevant as they have all invalid values

# %%
df_financial=df_financial.drop(['W1A1SJCSD','W1A1SJCDA','W1A1SJCDS','W1A1SJCCS','W1A1SJCSS'],axis=1)

# %%
df_financial
# Out:
#       W1A1SJ1  W1A1SJ2  W1A1SJ3  W1A1SJ4  W1A1SJ5  W1A1SJ6  W1A1SJ7  W1A1SJ8  \
# 0           8        5        9        8        5        2        3       31
# 1       99999    99999    99999    99999    99999    99999    99999    99999
# 2           6        6        8        8        8        2        3        9
# 3          98       10        9        9        9        1        4        2
# 4           1        7        3        1        8        3        2       23
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 7099        5        5        8        8        8        3        4       27
# 7100    99999    99999    99999    99999    99999    99999    99999    99999
# 7101        9        6        9        9        8        1        3        2
# 7102        8        6        8        7        7        2        2       18
# 7103        5        5        6        7        7        2        3       29
#
# ...

# %% [markdown]
# replacing 99999 with NaN in df_financial

# %%
df_financial.replace(99999, np.nan)
# Out:
#       W1A1SJ1  W1A1SJ2  W1A1SJ3  W1A1SJ4  W1A1SJ5  W1A1SJ6  W1A1SJ7  W1A1SJ8  \
# 0         8.0      5.0      9.0      8.0      5.0      2.0      3.0     31.0
# 1         NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2         6.0      6.0      8.0      8.0      8.0      2.0      3.0      9.0
# 3        98.0     10.0      9.0      9.0      9.0      1.0      4.0      2.0
# 4         1.0      7.0      3.0      1.0      8.0      3.0      2.0     23.0
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 7099      5.0      5.0      8.0      8.0      8.0      3.0      4.0     27.0
# 7100      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 7101      9.0      6.0      9.0      9.0      8.0      1.0      3.0      2.0
# 7102      8.0      6.0      8.0      7.0      7.0      2.0      2.0     18.0
# 7103      5.0      5.0      6.0      7.0      7.0      2.0      3.0     29.0
#
# ...

# %% [markdown]
# creating a new subset of demographics called as df_dem which includes columns of AGE, Gender, NO. OF CHILDREN, MARRIAGE STATUS, heart problems ever, PHYSICAL HEALTH, MENTAL OR EMOTIONAL HEALTH, and then replacing invalid values to NaN.

# %% [markdown]
# Age

# %%
df['W1A1PAGE_M2'].describe()
# Out:
# count    7104.000000
# mean       46.815597
# std        13.772770
# min        20.000000
# 25%        36.000000
# 50%        45.500000
# 75%        57.000000
# max        98.000000
# Name: W1A1PAGE_M2, dtype: float64

# %%
df['W1A1PAGE_M2'].replace(98, np.nan, inplace=True)

# %%
df['W1A1PAGE_M2'].describe()
# Out:
# count    7045.000000
# mean       46.386941
# std        13.005793
# min        20.000000
# 25%        36.000000
# 50%        45.000000
# 75%        56.000000
# max        75.000000
# Name: W1A1PAGE_M2, dtype: float64

# %% [markdown]
# Gender

# %%
df['W1A1PRSEX'].value_counts()
# Out:
# 2    3629
# 1    3394
# 8      81
# Name: W1A1PRSEX, dtype: int64

# %%
df['W1A1PRSEX'].replace(8, np.nan, inplace=True)

# %%
df['W1A1PRSEX'].value_counts()
# Out:
# 2.0    3629
# 1.0    3394
# Name: W1A1PRSEX, dtype: int64

# %% [markdown]
# NO. OF CHILDREN

# %%
df['W1CNT_BK'].value_counts()
# Out:
# 2     2023
# 99    1584
# 3     1291
# 1     1129
# 4      615
# 5      262
# 6      104
# 7       49
# 8       22
# 9       14
# 10      11
# Name: W1CNT_BK, dtype: int64

# %%
df['W1CNT_BK'].replace(99,np.nan,inplace=True)

# %%
df['W1CNT_BK'].value_counts()
# Out:
# 2.0     2023
# 3.0     1291
# 1.0     1129
# 4.0      615
# 5.0      262
# 6.0      104
# 7.0       49
# 8.0       22
# 9.0       14
# 10.0      11
# Name: W1CNT_BK, dtype: int64

# %% [markdown]
# MARRIAGE STATUS

# %%
df['W1A1PB24'].value_counts() # remove it entirely use - A1PB17 instead
# Out:
# 9    4662
# 2    2076
# 1     359
# 7       6
# 8       1
# Name: W1A1PB24, dtype: int64

# %%
df['W1A1PB24'].replace(7, np.nan,inplace=True)
df['W1A1PB24'].replace(8, np.nan,inplace=True)
df['W1A1PB24'].replace(9, np.nan,inplace=True)

# %%
df['W1A1PB24'].value_counts()
# Out:
# 2.0    2076
# 1.0     359
# Name: W1A1PB24, dtype: int64

# %% [markdown]
# heart problems ever

# %%
df['W1A1PA11'].value_counts()
# Out:
# 2    6169
# 1     915
# 7      20
# Name: W1A1PA11, dtype: int64

# %% [markdown]
# PHYSICAL HEALTH

# %%
df['W1A1PA4'].value_counts() # get rid of 7 as nan
# Out:
# 4    2505
# 3    2384
# 5    1217
# 2     796
# 1     192
# 7      10
# Name: W1A1PA4, dtype: int64

# %% [markdown]
# MENTAL OR EMOTIONAL HEALTH

# %%
df['W1A1PA5'].value_counts() # get rid of 7 as nan
# Out:
# 4    2443
# 3    2212
# 5    1851
# 2     520
# 1      69
# 7       9
# Name: W1A1PA5, dtype: int64

# %%
    df_sj_financial = df.filter(regex='A1SJ')

# %% [markdown]
# creating a new dataset called df_dem which has only demographic data

# %%
df_dem=df[['W1A1PAGE_M2','W1A1PRSEX','W1CNT_BK','W1A1PB24','W1A1PA11','W1A1PA4','W1A1PA5']]

# %%
df_dem
# Out:
#       W1A1PAGE_M2  W1A1PRSEX  W1CNT_BK  W1A1PB24  W1A1PA11  W1A1PA4  W1A1PA5
# 0            53.0        1.0       3.0       1.0         2        3        4
# 1            60.0        1.0       2.0       NaN         2        5        5
# 2            69.0        1.0       6.0       NaN         2        2        5
# 3            70.0        2.0       2.0       2.0         2        3        3
# 4            51.0        2.0       2.0       2.0         2        3        3
# ...           ...        ...       ...       ...       ...      ...      ...
# 7099         42.0        1.0       2.0       NaN         2        3        3
# 7100          NaN        1.0       2.0       NaN         2        3        4
# 7101         35.0        2.0       2.0       NaN         2        4        4
# 7102         35.0        2.0       3.0       NaN         2        5        4
# 7103         41.0        1.0       2.0       NaN         2        5        5
#
# [7104 rows x 7 columns]

# %%
df_dem.describe()
# Out:
#        W1A1PAGE_M2    W1A1PRSEX     W1CNT_BK     W1A1PB24     W1A1PA11  \
# count  7045.000000  7023.000000  5520.000000  2435.000000  7104.000000
# mean     46.386941     1.516731     2.571920     1.852567     1.885276
# std      13.005793     0.499756     1.379545     0.354610     0.431333
# min      20.000000     1.000000     1.000000     1.000000     1.000000
# 25%      36.000000     1.000000     2.000000     2.000000     2.000000
# 50%      45.000000     2.000000     2.000000     2.000000     2.000000
# 75%      56.000000     2.000000     3.000000     2.000000     2.000000
# max      75.000000     2.000000    10.000000     2.000000     7.000000
#
#            W1A1PA4      W1A1PA5
# count  7104.000000  7104.000000
# mean      3.534769     3.777449
# std       0.997351     0.956107
# min       1.000000     1.000000
# 25%       3.000000     3.000000
# 50%       4.000000     4.000000
# 75%       4.000000     5.000000
# max       7.000000     7.000000

# %% [markdown]
# Data Visualisation

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
age_x=df_dem['W1A1PAGE_M2']

# %%
plt.hist(age_x,bins=10,edgecolor='black')
# Out:
# (array([ 144.,  688., 1077.,  946., 1089.,  816.,  822.,  568.,  529.,
#          366.]),
#  array([20. , 25.5, 31. , 36.5, 42. , 47.5, 53. , 58.5, 64. , 69.5, 75. ]),
#  <a list of 10 Patch objects>)

# %%
df['W1A1PA11']
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 7099    2
# 7100    2
# 7101    2
# 7102    2
# 7103    2
# Name: W1A1PA11, Length: 7104, dtype: int64

# %%
df_dem['W1A1PAGE_M2'].describe()
# Out:
# count    7045.000000
# mean       46.386941
# std        13.005793
# min        20.000000
# 25%        36.000000
# 50%        45.000000
# 75%        56.000000
# max        75.000000
# Name: W1A1PAGE_M2, dtype: float64
